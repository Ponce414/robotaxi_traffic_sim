# %% [markdown]
# # Robo-Taxi Adoption Dynamics
#
# This notebook explores how the share of robo-taxis (RT) evolves over time in the LA traffic simulation model. We will use the shared core API to run scenarios with varying robo-taxi shares and visualize the impact on key metrics such as total VMT, average trip time, and congestion.
#
# ---
#
# **Outline:**
# 1. Import required libraries and model API
# 2. Run scenarios for different robo-taxi shares
# 3. Plot and analyze results

# %%
# %pip install matplotlib numpy

from pathlib import Path
import sys
import matplotlib.pyplot as plt
import numpy as np

# Ensure the project root (which contains graph_model.py) is in sys.path
PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "graph_model.py").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
	PROJECT_ROOT = PROJECT_ROOT.parent

if not (PROJECT_ROOT / "graph_model.py").exists():
	raise FileNotFoundError("Could not find 'graph_model.py' in any parent directory.")

if str(PROJECT_ROOT) not in sys.path:
	sys.path.insert(0, str(PROJECT_ROOT))

# Import required libraries and model API
from graph_model import SimParams, build_graph, run_scenario, get_baseline_vmt

# Build the LA road network graph
G = build_graph()
# Out:
# Requirement already satisfied: matplotlib in /Users/csithiphong/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: numpy in /Users/csithiphong/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/csithiphong/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/csithiphong/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/csithiphong/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages (from matplotlib) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/csithiphong/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/csithiphong/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/csithiphong/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/csithiphong/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/csithiphong/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/csithiphong/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/csithiphong/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.1)
# Requirement already satisfied: six>=1.5 in /Users/csithiphong/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Simulate Scenarios with Varying Robo-Taxi Share
#
# We will run the model for a range of `robotaxi_share` values from 0 to 1 and record key metrics for each scenario.

# %%
# %pip install scipy

# Define range of robo-taxi shares
rt_shares = np.linspace(0, 1, 11)
results = []

for share in rt_shares:
    params = SimParams(robotaxi_share=share)
    result = run_scenario(G, params)
    results.append({
        'robotaxi_share': share,
        'total_vmt': result['total_vmt'],
        'avg_trip_time_min': result['avg_trip_time_min'],
        'congested_edge_count': result['congested_edge_count'],
        'unmet_demand': result['unmet_demand'],
    })
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 7
#       5 for share in rt_shares:
#       6     params = SimParams(robotaxi_share=share)
# ----> 7     result = run_scenario(G, params)
#       8     results.append({
#       9         'robotaxi_share': share,
#      10         'total_vmt': result['total_vmt'],
#    (...)
#      13         'unmet_demand': result['unmet_demand'],
#      14     })
#
# File ~/Documents/Projects/robotaxi_traffic_sim/graph_model.py:309, in run_scenario(G, params)
#     307 def run_scenario(G: nx.DiGraph, params: SimParams) -> dict:
#     308     """Full scenario result: flow dicts + scalar readouts."""
# --> 309     return _simulate_internal(G, params)
#
# File ~/Documents/Projects/robotaxi_traffic_sim/graph_model.py:199, in _simulate_internal(G, params)
#     197     origin_demand[o] = origin_demand.get(o, 0.0) + f
#     198 if sum(origin_demand.values()) > 0:
# --> 199     pr = nx.pagerank(G, alpha=0.85, personalization=origin_demand)
#     200 else:
#     201     pr = {n: 1.0 / G.number_of_nodes() for n in G.nodes()}
#
# File ~/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages/networkx/utils/backends.py:412, in _dispatch.__call__(self, backend, *args, **kwargs)
#     409 def __call__(self, /, *args, backend=None, **kwargs):
#     410     if not backends:
#     411         # Fast path if no backends are installed
# --> 412         return self.orig_func(*args, **kwargs)
#     414     # Use `backend_name` in this function instead of `backend`
#     415     backend_name = backend
#
# File ~/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages/networkx/algorithms/link_analysis/pagerank_alg.py:110, in pagerank(G, alpha, personalization, max_iter, tol, nstart, weight, dangling)
#       9 @nx._dispatch(edge_attrs="weight")
#      10 def pagerank(
#      11     G,
#    (...)
#      18     dangling=None,
#      19 ):
#      20     """Returns the PageRank of the nodes in the graph.
#      21
#      22     PageRank computes a ranking of the nodes in the graph G based on
#    (...)
#     108
#     109     """
# --> 110     return _pagerank_scipy(
#     111         G, alpha, personalization, max_iter, tol, nstart, weight, dangling
#     112     )
#
# File ~/Documents/Projects/robotaxi_traffic_sim/.venv/lib/python3.9/site-packages/networkx/algorithms/link_analysis/pagerank_alg.py:453, in _pagerank_scipy(G, alpha, personalization, max_iter, tol, nstart, weight, dangling)
#     368 """Returns the PageRank of the nodes in the graph.
#     369
#     370 PageRank computes a ranking of the nodes in the graph G based on
#    (...)
#     450    http://dbpubs.stanford.edu:8090/pub/showDoc.Fulltext?lang=en&doc=1999-66&format=pdf
#     451 """
#     452 import numpy as np
# --> 453 import scipy as sp
#     455 N = len(G)
#     456 if N == 0:
#
# ModuleNotFoundError: No module named 'scipy'

# %% [markdown]
# ## Plot Results
#
# We will visualize how total VMT, average trip time, and congestion change as robo-taxi share increases.

# %%
# Convert results to arrays for plotting
robotaxi_shares = [r['robotaxi_share'] for r in results]
total_vmt = [r['total_vmt'] for r in results]
avg_trip_time = [r['avg_trip_time_min'] for r in results]
congested_edges = [r['congested_edge_count'] for r in results]
unmet_demand = [r['unmet_demand'] for r in results]

fig, axs = plt.subplots(2, 2, figsize=(12, 8))

axs[0, 0].plot(robotaxi_shares, total_vmt, marker='o')
axs[0, 0].set_title('Total VMT vs Robo-Taxi Share')
axs[0, 0].set_xlabel('Robo-Taxi Share')
axs[0, 0].set_ylabel('Total VMT')

axs[0, 1].plot(robotaxi_shares, avg_trip_time, marker='o', color='orange')
axs[0, 1].set_title('Avg Trip Time vs Robo-Taxi Share')
axs[0, 1].set_xlabel('Robo-Taxi Share')
axs[0, 1].set_ylabel('Avg Trip Time (min)')

axs[1, 0].plot(robotaxi_shares, congested_edges, marker='o', color='green')
axs[1, 0].set_title('Congested Edges vs Robo-Taxi Share')
axs[1, 0].set_xlabel('Robo-Taxi Share')
axs[1, 0].set_ylabel('Congested Edge Count')

axs[1, 1].plot(robotaxi_shares, unmet_demand, marker='o', color='red')
axs[1, 1].set_title('Unmet Demand vs Robo-Taxi Share')
axs[1, 1].set_xlabel('Robo-Taxi Share')
axs[1, 1].set_ylabel('Unmet Demand')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Discussion
#
# - **Total VMT**: Shows how vehicle miles traveled changes as robo-taxi share increases.
# - **Average Trip Time**: Indicates the impact on user travel time.
# - **Congested Edges**: Reflects network congestion.
# - **Unmet Demand**: Shows if the fleet cap is binding at high robo-taxi shares.
#
# Interpret the trends and discuss implications for robo-taxi adoption policy.
